# %%
#config box

d = {'key1':'val1', 'key2':'val2'}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({'key1':'val1', 'key2':'val2'})

# %%
d2.key1
# Out:
# 'val1'

# %%
#ensure annotation

def mul(x:int, y:int)->int:
    return x*y

# %%
mul(2,'3')
# Out:
# '33'

# %%
from ensure import ensure_annotations

@ensure_annotations

def mul(x:int, y:int)->int:
    return x*y

# %%
mul(2,3)
# Out:
# 6

# %%
mul(2,'3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 mul(2,'3')
#
# File ~/Kidney-Disease-Classification-MLOps/.kidney/lib64/python3.8/site-packages/ensure/main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function mul at 0x7f3f28b10c10> does not match annotation type <class 'int'>

# %%
import gdown

# %%
url = 'https://drive.google.com/file/d/1IS35XpjMG9GTR4JSYvTLXbIVcyHcmbd-/view?usp=sharing'
file_id = url.split('/')[-2]
file_id
# Out:
# '1IS35XpjMG9GTR4JSYvTLXbIVcyHcmbd-'

# %%
prefix_id = 'https://drive.google.com/uc?export=download&id='

gdown.download(prefix_id+file_id,'dataset.zip')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1IS35XpjMG9GTR4JSYvTLXbIVcyHcmbd-
# From (redirected): https://drive.google.com/uc?export=download&id=1IS35XpjMG9GTR4JSYvTLXbIVcyHcmbd-&confirm=t&uuid=4bf5725b-aa44-4701-b73d-8662247866dc
# To: /home/amit/Kidney-Disease-Classification-MLOps/research/dataset.zip
# 100%|██████████| 164M/164M [00:13<00:00, 12.1MB/s]
# 'dataset.zip'
